# %% [markdown]
# ### Process .PAL lut file to c array

# %%
import ipywidgets as widgets

# %%
fileNameInput = widgets.Text(
    value='*.pal',
    placeholder='Type pal file',
    description='file:',
    disabled=False
)
processButton = widgets.Button(
    value=False,
    description='Process',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Description',
    icon='check'
)
placeHolder = widgets.VBox([fileNameInput,processButton])
#b,g,r,a   low->high
def ProcessPAL(b):
    fileName = fileNameInput.value
    with open(fileName,'r') as file:

        allData = file.readlines()
        colorNums = int(allData[2])
        colorList = []
        print(colorNums)
        for i in range(colorNums):
            currentLine = allData[i+3]
            currentLine = currentLine.split(' ')
            red=int(currentLine[0])
            green=int(currentLine[1])
            blue=int(currentLine[2])
            colorList.append((red<<16)|(green<<8)|(blue)|(0xff<<24))
    for i in range(colorNums):
        print('%#08X'%(colorList[i]))
    with open(fileName[:-3]+'c','w') as outputFile: 
        outputFile.write('//Order is b g r a, low->high\n')
        outputFile.write('const uint32_t pal['+str(colorNums)+']={\n')
        for i in range(colorNums):
            outputFile.write('\t%#08X,\n'%(colorList[i]))
        outputFile.write('};\n')
        
processButton.on_click(ProcessPAL)
placeHolder
# Out:
# ...
# 16
# 0XFF000000
# 0XFF94A5AC
# 0XFF311894
# 0XFFF66D62
# 0XFFD579BD
# 0XFFFFDA31
# 0XFFB41008
# 0XFFE65052
# 0XFF730800
# 0XFF0099E6
# 0XFF1895E6
# 0XFFFFFFFF
# 0XFFE61C20
# 0XFFE6696A
# 0XFF00AAF6
# 0XFFAC0808

# %%
#256 color 
from PIL import Image

pngNameInput = widgets.Text(
    value='*.png',
    placeholder='Type png file',
    description='file:',
    disabled=False
)
processButton = widgets.Button(
    value=False,
    description='Process',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Description',
    icon='check'
)
def ProcessImg(Img):
    pngName = pngNameInput.value

    im = Image.open(pngName)
    x,y = im.size
    testPal = im.getpalette()    
    imData = im.load()
    indexVal =[]
    for i in range(y):
        for j in range(x):
            lowPixel = imData[j,i]
            indexVal.append(lowPixel)
    #print(indexVal)
    dataLength = len(indexVal)
    with open(pngName[:-3]+'c','w') as outputFile: 
        outputFile.write('//image size %d ,%d\n'%(x,y))
        outputFile.write('const uint8_t img['+str(dataLength)+']={\n')
        left = dataLength%16
        for i in range(int(dataLength/16)):
            outputFile.write('\t')
            for j in range(16):
                outputFile.write('%#02X, '%indexVal[16*i+j])
            outputFile.write('\n')
        if left != 0:
            for k in range(left):
                outputFile.write('\t')
                outputFile.write('%#02X, '%indexVal[int(dataLength/16)+k])
            outputFile.write('\n')    
        outputFile.write('};\n')        
processButton.on_click(ProcessImg)
placeHolder = widgets.VBox([pngNameInput,processButton])
placeHolder

# %%
im = Image.open(r'D:\project\3d\Sprite-0001.png')
pixels = im.load()
im.data
# Out:
# (16, 16)

# %%
#16 color
from PIL import Image

pngNameInput = widgets.Text(
    value='*.png',
    placeholder='Type png file',
    description='file:',
    disabled=False
)
processButton = widgets.Button(
    value=False,
    description='Process',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Description',
    icon='check'
)
def ProcessImg(Img):
    pngName = pngNameInput.value

    im = Image.open(pngName)
    x,y = im.size
    testPal = im.getpalette()    
    imData = im.load()
    indexVal =[]
    for i in range(y):
        for j in range(x//2):
            lowPixel = imData[j*2,y-1-i]
            highPixel = imData[j*2+1,y-1-i]
            #print(lowPixel)
            #print(highPixel)
            finalVal = (highPixel<<4)|(lowPixel)
            indexVal.append(finalVal)

    dataLength = len(indexVal)
    with open(pngName[:-3]+'c','w') as outputFile: 
        outputFile.write('//image size %d ,%d\n'%(x,y))
        outputFile.write('const uint8_t img['+str(dataLength)+']={\n')
        left = dataLength%16
        for i in range(int(dataLength/16)):
            outputFile.write('\t')
            for j in range(16):
                outputFile.write('%#02X, '%indexVal[16*i+j])
            outputFile.write('\n')
        if left != 0:
            for k in range(left):
                outputFile.write('\t')
                outputFile.write('%#02X, '%indexVal[int(dataLength/16)+k])
            outputFile.write('\n')    
        outputFile.write('};\n')        
processButton.on_click(ProcessImg)
placeHolder = widgets.VBox([pngNameInput,processButton])
placeHolder
# Out:
# ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-9e3202ba41db> in ProcessImg(Img)
#      19     pngName = pngNameInput.value
#      20
# ---> 21     im = Image.open(pngName)
#      22     x,y = im.size
#      23     testPal = im.getpalette()
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2764
#    2765     if filename:
# -> 2766         fp = builtins.open(filename, "rb")
#    2767         exclusive_fp = True
#    2768
#
# OSError: [Errno 22] Invalid argument: '*.png'
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# ...
